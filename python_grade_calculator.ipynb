# %% [markdown]
# ## Calculator
#
# - **90 or above A**
# - **80 or above B**
# - **70 or above C**
# - **50 or above D**
# - **49 or below F**

# %%
percentage = float(input('What is your percentage?'))

if   percentage >= 90:
    grade = 'A'
elif percentage >= 80: 
    grade = 'B'
elif percentage >= 70:
    grade = 'C'
elif percentage >= 50:
    grade = 'D'
else:
    grade = 'F'

print(f'Student,s grade is {grade}')
# Out:
# Student,s grade is F
